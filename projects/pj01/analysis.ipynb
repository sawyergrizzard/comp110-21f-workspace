# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## **Hypothesis:** I expect that over 80% of the student body is enrolled in at least one in-person class."

# %%
from data_utils import read_csv_rows, columnar

data_rows: list[dict[str, str]] = read_csv_rows('../../data/survey.csv')
columns: dict[str, list[str]] = columnar(data_rows)

# %% [markdown]
# ### Next, I will select just the in_person_classes column. Here are the first five rows:

# %%
from data_utils import head, select
subset: dict[str, list[str]] = select(columns, ["in_person_classes"])
head(subset, 5)
# Out:
# {'in_person_classes': ['',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   '',
#   '',
#   '',
#   '',
#   'No',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'No',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'No',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   'Yes',
#   '',
#   '',
#   '',
#   '',
#   'Yes']}

# %% [markdown]
# ### Now I will count up the totals of each.

# %%
from data_utils import count
counts = count(subset['in_person_classes'])

print(f"In person total is: {counts['Yes']}")
print(f"No in person total is: {counts['No']}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/7r/k0hm_ls10dbckp1nm_4ny4gm0000gn/T/ipykernel_41446/206472959.py in <module>
#       2 counts = count(subset['in_person_classes'])
#       3
# ----> 4 print(f"In person total is: {counts['Yes']}")
#       5 print(f"No in person total is: {counts['No']}")
#
# KeyError: 'Yes'

# %% [markdown]
# ## **Conclusion:** I have not yet processed the data.
